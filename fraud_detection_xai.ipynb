# %% [markdown]
# <a href="https://colab.research.google.com/github/roksanajagoda/xai-financial-anomaly-detection/blob/master/fraud_detection_xai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install shap
# !pip install xgboost
# !pip install scikit-learn
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
